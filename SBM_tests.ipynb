# %% [markdown]
# # SBM Graphs

# %%
from algorithms.modularity_based import *
from algorithms.spectral import *
from algorithms.statistical import *

from SBM.sbm_generation import *
from validation import *
from running_time import *

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
n = 4000

# %% [markdown]
# ## Validation

# %%
range_K = [4, 5, 8, 10, 20, 30, 40, 50, 100]
print(range_K)
# Out:
# [4, 5, 8, 10, 20, 30, 40, 50, 100]

# %%
res_mean_K, nb_clusters_K = validation_range_K(range_K, n=n)

# %%
res_mean_p, nb_clusters_p = validation_range_p(range_p=None, K = 5, n=n)

# %%
range_p_zoom = np.linspace(0.0, 0.04, 11)
res_mean_p_zoom, nb_clusters_p_zoom = validation_range_p(range_p=None, K = 5)

# %%
res_mean_n, nb_clusters_n = validation_range_n()

# %% [markdown]
# ## Running Time

# %%
res_rt_vs_n = running_time_vs_n()

# %%
res_rt_vs_K = running_time_vs_K()

# %%
# [OK] modifier validation pour prendre block_membership en arg
# [OK] faire run pour des plus grands n (1000, 5000, 10000, 25000, 50000, ...) avec le reste fixé 
# regarder le nb de edge et voir si c'est a peu pret le meme pour chaque run
