# %% [markdown]
# # SBM Graphs

# %%
from algorithms.modularity_based import *
from algorithms.spectral import *
from algorithms.statistical import *

from SBM.sbm_generation import *
from validation import *
from running_time import *

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
n = 3000
n_graphs = 5
range_K = [4, 5, 8, 10, 20, 30, 50, 80, 100, 150]

# %% [markdown]
# ## Validation

# %%
res_mean_K, nb_clusters_K = validation_range_K(range_K, n=n, n_graphs = n_graphs)
# WHen p_in = p_out, results near 0 for all score except fowlkes (max=0.35)

# %%
res_mean_p, nb_clusters_p = validation_range_p(range_p=None, K = 8, n=n, n_reps=n_graphs)

# %%
range_p_zoom = np.linspace(0.0, 0.025, 15)
range_p_zoom[4]
# Out:
# np.float64(0.0071428571428571435)

# %%
2*8*np.log(n)/(6*n)
# Out:
# np.float64(0.0071167711712446634)

# %%
range_p_zoom = np.linspace(0.0, 0.025, 15)
res_mean_p_zoom, nb_clusters_p_zoom = validation_range_p(range_p=range_p_zoom, K = 8, n=n, n_reps=5)

# %%
range_n = [1000, 3000, 5000, 7500, 10000, 12000]
res_mean_n, nb_clusters_n = validation_range_n(range_n=range_n, K=20)

# %% [markdown]
# ## Running Time

# %% [markdown]
# ### rt vs n

# %%
range_n = [2000, 4000, 6000, 8000, 10000, 12000]

# %%
res_rt_vs_n = running_time_vs_n(range_n=range_n, metric="adjusted_mutual_info_score")

# %% [markdown]
# ### rt vt K

# %%
res_rt_vs_K = running_time_vs_K(range_K=range_K, metric="adjusted_mutual_info_score", n=n)
