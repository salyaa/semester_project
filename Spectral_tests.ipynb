# %% [markdown]
# # Validation for the Spectral Clustering Algorithms

# %%
from ABCD.abcd_generation import *
from SBM.sbm_generation import *

from validation import *
from running_time import *

from constants import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
n = 3000
n_graphs = 5 
range_K = [4, 5, 8, 10, 20, 25, 40, 50]
algos = algorithms_sc

# %% [markdown]
# ## ABCD

# %% [markdown]
# ### Validation

# %%
res_K, nb_K = validation_range_K(range_K=range_K, n=n, n_graphs = n_graphs, graph_type="abcd", possible_algorithms=algos)

# %%
range_n = [1000, 3000, 5000, 7500, 10000, 12000]
res_n, nb_n = validation_range_n(range_n=range_n, K=20, n_graphs=1, graph_type="abcd", possible_algorithms=algos)

# %%
res_xi, nb_xi = validation_range_p(K=8, n=4000, n_reps = n_graphs, graph_type="abcd", possible_algorithms=algos)

# %% [markdown]
# ### Running Time

# %%
rt_vs_n = running_time_vs_n(K=8, graph_type="abcd", n_runs=1, possible_algorithms=algos)

# %%
rt_vs_k = running_time_vs_K(range_K=range_K, n=n, metric="adjusted_mutual_info_score", graph_type="abcd", n_runs=1, possible_algorithms=algos)

# %% [markdown]
# ## SBM

# %%
res_K_SBM, nb_K_SBM = validation_range_K(range_K=range_K, n=n, n_graphs = 1, possible_algorithms=algos)

# %%
res_p_SBM, nb_p_SBM = validation_range_p(K=8, n=n, n_reps = 1, possible_algorithms=algos)

# %%
range_p_zoom = np.linspace(0.0, 0.04, 11)
res_p_zoom_SBM, nb_p_zoom_SBM = validation_range_p( range_p=range_p_zoom, K=8, n=n, n_reps = 1, possible_algorithms=algos)

# %%
res_n_SBM, nb_n_SBM = validation_range_n(K=3,possible_algorithms=algos)

# %%
range_n = [1000, 2500, 4000, 5000, 6000, 8000]
res_rt_vs_n_SBM = running_time_vs_n(range_n=range_n, possible_algorithms=algos)

# %%
res_rt_vs_K_SBM = running_time_vs_K(n=n, possible_algorithms=algos)
