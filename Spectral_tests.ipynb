# %% [markdown]
# # Validation for the Spectral Clustering Algorithms

# %%
from ABCD.abcd_generation import *
from SBM.sbm_generation import *

from validation import *
from running_time import *

from constants import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
n = 4000
range_K = [4, 5, 8, 10, 20, 25, 40, 50]
algos = algorithms_sc

# %% [markdown]
# ## ABCD

# %%
res_K, nb_K = validation_range_K(range_K=range_K, n=n, n_graphs = 1, graph_type="abcd", possible_algorithms=algos)

# %%
display(res_K)
# Out:
#                                   sc_bm   sc_dcbm   sc_pabm   orth_sc
# K  Metric
# 4  adjusted_mutual_info_score  0.001344  0.000090  0.000092 -0.000340
#    adjusted_rand_score         0.000591  0.000618 -0.000013  0.000288
#    v_measure_score             0.003878  0.000414  0.000967  0.000359
#    homogeneity_score           0.000931  0.000785  0.000174  0.001018
#    fowlkes_mallows_score       0.341941  0.258728  0.272053  0.281121
# 5  adjusted_mutual_info_score -0.000285 -0.000018  0.000457  0.000054
#    adjusted_rand_score        -0.000111 -0.000217  0.000281  0.000050
#    v_measure_score             0.002135  0.001438  0.000564  0.001631
#    homogeneity_score           0.000917  0.001813  0.000704  0.001226
#    fowlkes_mallows_score       0.274945  0.209841  0.219999  0.231623
# 8  adjusted_mutual_info_score  0.002507  0.003074  0.000948 -0.000547
#    adjusted_rand_score         0.000823  0.000186 -0.000577 -0.000063
#    v_measure_score             0.006957  0.004333  0.002977  0.003545
#    homogeneity_score           0.005410  0.002727  0.003228  0.001850
#    fowlkes_mallows_score       0.241967  0.144992  0.163663  0.160749
# 10 adjusted_mutual_info_score  0.001889  0.003778  0.001637 -0.000590
#    adjusted_rand_score         0.001016  0.000401 -0.000245  0.000055
#    v_measure_score             0.011458  0.007684  0.005156  0.003596
#    homogeneity_score           0.006479  0.004595  0.003981  0.004281
#    fowlkes_mallows_score       0.188444  0.115315  0.133605  0.140411

# %%
res_n, nb_n = validation_range_n(K=3, n_graphs = 1, graph_type="abcd", possible_algos=algos)

# %%
res_xi, nb_xi = validation_range_p(K=8, n=4000, n_reps = 1, graph_type="abcd", possible_algos=algos)
