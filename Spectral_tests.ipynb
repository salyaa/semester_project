# %% [markdown]
# # Validation for the Spectral Clustering Algorithms

# %%
from ABCD.abcd_generation import *
from SBM.sbm_generation import *

from validation import *
from running_time import *

from constants import *

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
n = 3000
n_graphs = 1
range_K = [4, 5, 8, 10, 20, 25]
algos = algorithms_sc

# %% [markdown]
# ## ABCD

# %% [markdown]
# ### Validation

# %%
res_K, nb_K = validation_range_K(range_K=range_K, n=n, n_graphs = 1, graph_type="abcd", possible_algorithms=algos)

# %%
res_n, nb_n = validation_range_n(K=3, n_graphs=1, graph_type="abcd", possible_algorithms=algos)

# %%
res_xi, nb_xi = validation_range_p(K=8, n=4000, n_reps = 1, graph_type="abcd", possible_algorithms=algos)

# %% [markdown]
# ### Running Time

# %%
rt_vs_n = running_time_vs_n(K=8, graph_type="abcd", n_runs=1, possible_algorithms=algos)

# %%
rt_vs_k = running_time_vs_K(range_K=range_K, n=n, graph_type="abcd", n_runs=1, possible_algorithms=algos)
